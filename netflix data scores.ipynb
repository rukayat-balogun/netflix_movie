# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path = "C:/Users/Rukayat Balogun/Documents/my csv file/"
file_name = "NetflixOriginals.csv"
read_file = pd.read_csv(f"{path}{file_name}", encoding='latin-1')

# %%
read_file
# Out:
#                                            Title                  Genre  \
# 0                                Enter the Anime            Documentary
# 1                                    Dark Forces               Thriller
# 2                                        The App  Science fiction/Drama
# 3                                 The Open House        Horror thriller
# 4                                    Kaali Khuhi                Mystery
# ..                                           ...                    ...
# 579        Taylor Swift: Reputation Stadium Tour           Concert Film
# 580  Winter on Fire: Ukraine's Fight for Freedom            Documentary
# 581                      Springsteen on Broadway           One-man show
# 582    Emicida: AmarElo - It's All For Yesterday            Documentary
# 583     David Attenborough: A Life on Our Planet            Documentary
#
#               Premiere  Runtime  IMDB Score                  Language
# ...

# %%
len(read_file['Title'].unique())
# Out:
# 584

# %%
read_file[~read_file['Title'].duplicated()] #this checks if there are duplicate values
# Out:
#                                            Title                  Genre  \
# 0                                Enter the Anime            Documentary
# 1                                    Dark Forces               Thriller
# 2                                        The App  Science fiction/Drama
# 3                                 The Open House        Horror thriller
# 4                                    Kaali Khuhi                Mystery
# ..                                           ...                    ...
# 579        Taylor Swift: Reputation Stadium Tour           Concert Film
# 580  Winter on Fire: Ukraine's Fight for Freedom            Documentary
# 581                      Springsteen on Broadway           One-man show
# 582    Emicida: AmarElo - It's All For Yesterday            Documentary
# 583     David Attenborough: A Life on Our Planet            Documentary
#
#               Premiere  Runtime  IMDB Score                  Language
# ...

# %%
read_file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 584 entries, 0 to 583
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Title       584 non-null    object
#  1   Genre       584 non-null    object
#  2   Premiere    584 non-null    object
#  3   Runtime     584 non-null    int64
#  4   IMDB Score  584 non-null    float64
#  5   Language    584 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 27.5+ KB

# %%
# convert the 'Date' column to datetime format
read_file['Premiere']= pd.to_datetime(read_file['Premiere'])

# %%
read_file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 584 entries, 0 to 583
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Title       584 non-null    object
#  1   Genre       584 non-null    object
#  2   Premiere    584 non-null    datetime64[ns]
#  3   Runtime     584 non-null    int64
#  4   IMDB Score  584 non-null    float64
#  5   Language    584 non-null    object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(3)
# memory usage: 27.5+ KB

# %%
read_file
# Out:
#                                            Title                  Genre  \
# 0                                Enter the Anime            Documentary
# 1                                    Dark Forces               Thriller
# 2                                        The App  Science fiction/Drama
# 3                                 The Open House        Horror thriller
# 4                                    Kaali Khuhi                Mystery
# ..                                           ...                    ...
# 579        Taylor Swift: Reputation Stadium Tour           Concert Film
# 580  Winter on Fire: Ukraine's Fight for Freedom            Documentary
# 581                      Springsteen on Broadway           One-man show
# 582    Emicida: AmarElo - It's All For Yesterday            Documentary
# 583     David Attenborough: A Life on Our Planet            Documentary
#
#       Premiere  Runtime  IMDB Score                  Language
# ...

# %%
read_file.sort_values(by='Premiere', inplace=True) # This now sorts in date order

# %%
read_file
# Out:
#                                                 Title         Genre  \
# 304                                        My Own Man   Documentary
# 519  The Other One: The Long Strange Trip of Bob Weir   Documentary
# 228                                  Hot Girls Wanted   Documentary
# 550                       What Happened, Miss Simone?   Documentary
# 531                                               Tig   Documentary
# ..                                                ...           ...
# 194                                  Army of the Dead  Zombie/Heist
# 245                       Baggio: The Divine Ponytail        Biopic
# 71                                          Ghost Lab        Horror
# 275                              Nail Bomber: Manhunt   Documentary
# 369                                      Blue Miracle         Drama
#
#       Premiere  Runtime  IMDB Score Language
# 304 2014-12-13       81         6.4  English
# 519 2015-05-22       83         7.3  English
# ...

# %%
len(read_file['Genre'].unique())
# Out:
# 115

# %%
read_file.sort_values(by='Premiere', inplace=True, ascending=False) # This now sorts in date order
read_file
# Out:
#                                                 Title         Genre  \
# 369                                      Blue Miracle         Drama
# 275                              Nail Bomber: Manhunt   Documentary
# 71                                          Ghost Lab        Horror
# 245                       Baggio: The Divine Ponytail        Biopic
# 194                                  Army of the Dead  Zombie/Heist
# ..                                                ...           ...
# 531                                               Tig   Documentary
# 550                       What Happened, Miss Simone?   Documentary
# 228                                  Hot Girls Wanted   Documentary
# 519  The Other One: The Long Strange Trip of Bob Weir   Documentary
# 304                                        My Own Man   Documentary
#
#       Premiere  Runtime  IMDB Score Language
# 369 2021-05-27       95         6.7  English
# 275 2021-05-26       72         6.3  English
# ...

# %%
read_file["runtime/imdb_score"] = round(read_file['Runtime'] / read_file["IMDB Score"],0)

# %%
read_file
# Out:
#                                                 Title         Genre  \
# 369                                      Blue Miracle         Drama
# 275                              Nail Bomber: Manhunt   Documentary
# 71                                          Ghost Lab        Horror
# 245                       Baggio: The Divine Ponytail        Biopic
# 194                                  Army of the Dead  Zombie/Heist
# ..                                                ...           ...
# 531                                               Tig   Documentary
# 550                       What Happened, Miss Simone?   Documentary
# 228                                  Hot Girls Wanted   Documentary
# 519  The Other One: The Long Strange Trip of Bob Weir   Documentary
# 304                                        My Own Man   Documentary
#
#       Premiere  Runtime  IMDB Score Language  runtime/imdb_score
# 369 2021-05-27       95         6.7  English                14.0
# ...

# %%
color_code = (200/255,82/255,0/255)
fig = plt.figure(figsize=(15,9))
plt.plot(read_file["Premiere"], read_file["runtime/imdb_score"], c= color_code)
plt.xlabel("Premiere")
plt.ylabel("runtime/imdb_score")
plt.title("Premier of movie Vs runtime/imdb_score")
plt.xticks(rotation=45)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set()

# %%
sns.pairplot(read_file)

# %%
read_file['year'] = read_file['Premiere'].dt.year
plt.figure(figsize=(8,6))
sns.countplot(x='year',data=read_file,palette='bright') 
#2015 had second lowest amount of movies released
